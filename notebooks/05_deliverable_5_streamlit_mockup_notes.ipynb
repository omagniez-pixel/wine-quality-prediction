# %% [markdown]
# # Deliverable 5 - Streamlit Mock-up Notes
#
# This notebook summarizes the Streamlit prototype and the expected screenshots.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
PROJECT_ROOT = Path.cwd()
if (PROJECT_ROOT / 'wine_quality_project').exists():
    PROJECT_ROOT = PROJECT_ROOT / 'wine_quality_project'
elif PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
print('PROJECT_ROOT =', PROJECT_ROOT)
app_path = PROJECT_ROOT / 'src/app.py'
plot_path = PROJECT_ROOT / 'plots/plot_3_model_performance_macro_f1.png'
print('App exists:', app_path.exists())
print('Performance plot exists:', plot_path.exists())
print('Command: python3 -m streamlit run src/app.py')
# Out:
# PROJECT_ROOT = /Users/oscarmagniez/Desktop/Python/vin_project/wine_quality_project
# App exists: True
# Performance plot exists: True
# Command: streamlit run src/app.py

# %% [markdown]
# The prototype prediction is intentionally mocked. Connecting the final model is listed as a next step.
