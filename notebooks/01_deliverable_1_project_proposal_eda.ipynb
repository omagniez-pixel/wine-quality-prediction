# %% [markdown]
# # Deliverable 1 - Project Proposal EDA
#
# Simple EDA notebook for the Wine Quality project.

# %%
from pathlib import Path
import pandas as pd
import numpy as np
PROJECT_ROOT = Path.cwd()
if (PROJECT_ROOT / 'wine_quality_project').exists():
    PROJECT_ROOT = PROJECT_ROOT / 'wine_quality_project'
elif PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
print('PROJECT_ROOT =', PROJECT_ROOT)

red = pd.read_csv(PROJECT_ROOT / 'data/raw/winequality-red.csv', sep=';')
white = pd.read_csv(PROJECT_ROOT / 'data/raw/winequality-white.csv', sep=';')
red['wine_type'] = 'red'
white['wine_type'] = 'white'
wine = pd.concat([red, white], ignore_index=True)
wine['quality_group'] = wine['quality'].apply(lambda q: 'low quality' if q <= 5 else ('medium quality' if q == 6 else 'high quality'))
print('Red rows:', len(red))
print('White rows:', len(white))
print('Total rows:', len(wine))
print('Columns:', wine.shape[1])
# Out:
# PROJECT_ROOT = /Users/oscarmagniez/Desktop/Python/vin_project/wine_quality_project
# Red rows: 1599
# White rows: 4898
# Total rows: 6497
# Columns: 14

# %%
wine.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# wine_type                object
# quality_group            object
# dtype: object

# %%
wine.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# wine_type               0
# quality_group           0
# dtype: int64

# %%
wine['quality'].value_counts().sort_index()
# Out:
# quality
# 3      30
# 4     216
# 5    2138
# 6    2836
# 7    1079
# 8     193
# 9       5
# Name: count, dtype: int64

# %%
wine['quality_group'].value_counts().reindex(['low quality','medium quality','high quality'])
# Out:
# quality_group
# low quality       2384
# medium quality    2836
# high quality      1277
# Name: count, dtype: int64

# %%
print('Time variables:', [c for c in wine.columns if 'date' in c.lower() or 'time' in c.lower()])
print('Categorical variables:', wine.select_dtypes(include='object').columns.tolist())
# Out:
# Time variables: []
# Categorical variables: ['wine_type', 'quality_group']

# %%
wine.drop(columns=['quality_group']).describe().T[['min','max','mean','std']]
# Out:
#                           min        max        mean        std
# fixed acidity         3.80000   15.90000    7.215307   1.296434
# volatile acidity      0.08000    1.58000    0.339666   0.164636
# citric acid           0.00000    1.66000    0.318633   0.145318
# residual sugar        0.60000   65.80000    5.443235   4.757804
# chlorides             0.00900    0.61100    0.056034   0.035034
# free sulfur dioxide   1.00000  289.00000   30.525319  17.749400
# total sulfur dioxide  6.00000  440.00000  115.744574  56.521855
# density               0.98711    1.03898    0.994697   0.002999
# pH                    2.72000    4.01000    3.218501   0.160787
# sulphates             0.22000    2.00000    0.531268   0.148806
# alcohol               8.00000   14.90000   10.491801   1.192712
# quality               3.00000    9.00000    5.818378   0.873255

# %% [markdown]
# Comments: the data is tabular, without time variables, mainly numerical, with `wine_type` as the created categorical variable.
